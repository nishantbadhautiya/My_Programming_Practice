# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline 
# %reload_ext autoreload 
# %autoreload 2

# %%
sns.get_dataset_names()

# %%
crash_df = sns.load_dataset('car_crashes')

# %%
crash_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.distplot(crash_df['not_distracted'], kde=True, hist=True, color='g', bins=20)
# Out:
# /tmp/ipykernel_120850/4129729449.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'], kde=True, hist=True, color='g', bins=20)
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %%
sns.jointplot(data=crash_df, x='speeding', y='alcohol', kind='kde')

# %%
sns.kdeplot(data=crash_df['alcohol'], color='r')
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
# sns.pairplot(data=crash_df)

tips_df = sns.load_dataset('tips') 
sns.pairplot(data=tips_df, hue='sex', palette='Reds')
# Out:
# /home/nishant/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.rugplot(crash_df['speeding'])
# Out:
# <Axes: xlabel='speeding'>

# %%
sns.set_style('ticks')
plt.figure(figsize=(8,4))
sns.set_context(context='paper', font_scale=1.5)
sns.jointplot(data=crash_df, x=crash_df['speeding'], y=crash_df['alcohol'], kind='reg')
sns.despine(left=True, right=True, bottom=True,top=True)

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(data=tips_df, x='sex', y='total_bill', estimator=np.cov)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(data=tips_df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(data=tips_df, x='day', y='total_bill', hue='sex')
plt.legend(loc=0)

# %%
sns.violinplot(data=tips_df, x='day', y='total_bill', hue='sex', split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(data=tips_df, x='day', y='total_bill', hue='sex', jitter=True, dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips_df, x='day', y='total_bill')
sns.swarmplot(data=tips_df, x='day', y='total_bill', color='white')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips_df, x='day', y='total_bill', hue='sex', palette='ocean')
plt.legend(loc = 'upper right')

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)
# To create a heatmap with data you must have data set up as a matrix where variables
# are on the columns and rows

# Correlation tells you how influential a variable is on the result
# So we see that n previous accident is heavily correlated with accidents, while the
# insurance premium is not
crash_mx = crash_df.corr()

# Create the heatmap, add annotations and a color map
sns.heatmap(crash_mx, annot=True, cmap='Blues')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 9
#       2 sns.set_context('paper', font_scale=1.4)
#       3 # To create a heatmap with data you must have data set up as a matrix where variables
#       4 # are on the columns and rows
#       5
#       6 # Correlation tells you how influential a variable is on the result
#       7 # So we see that n previous accident is heavily correlated with accidents, while the
#       8 # insurance premium is not
# ----> 9 crash_mx = crash_df.corr()
#      11 # Create the heatmap, add annotations and a color map
#      12 sns.heatmap(crash_mx, annot=True, cmap='Blues')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# ...
