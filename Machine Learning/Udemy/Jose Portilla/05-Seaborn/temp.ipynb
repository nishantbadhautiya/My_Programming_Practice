# %%
import pandas as pd

# %%
df = pd.read_csv('application_record.csv')

# %%
df.shape
# Out:
# (438557, 18)

# %%
df.shape[0] / 2
# Out:
# 219278.5

# %%
df = pd.read_csv('application_record.csv', nrows=219278)

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 219273  5969499           F            N               N             0
# 219274  5969500           F            N               N             0
# 219275  5969501           F            N               N             0
# 219276  5969505           F            N               Y             3
# 219277  5969506           F            N               Y             3
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df.shape
# Out:
# (219278, 18)

# %%
df.to_csv('application_record2.csv')
